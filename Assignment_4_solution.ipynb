# %%
#1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below
# formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass.

# %%
import math as m

# %%
class Triangle:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c

# %%
class Area_Of_Triangle(Triangle):
    def __init__(self,*args):
        super(Area_Of_Triangle,self).__init__(*args)
    
    def area(self,*args):
        s=(self.a+self.b+self.c)/2
        area =m.sqrt(s*(s-self.a)*(s-self.b)*(s-self.c))
        return f"The area of Triangle of sides {self.a},{self.b},{self.c} is {area}."

# %%
t=Area_Of_Triangle(3,4,5)

# %%
t.area()
# Out:
# 'The area of Triangle of sides 3,4,5 is 6.0.'

# %%
#1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns the list of words that are longer than n.

# %%
def filter_long_words(my_lst,n):
    l=[]
    for item in my_lst:
        if len(item)>n:
            l.append(item)
    print(l)

# %%
lst=["sultan","sahil","shaikh","khan","sudhanshu","ineuron","krish","naik"]

# %%
filter_long_words(lst,6)
# Out:
# ['sudhanshu', 'ineuron']

# %%
# 2.1 Write a Python program using function concept that maps list of words into a list of integers
# representing the lengths of the corresponding words.
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
# Here 2,3 and 4 are the lengths of the words in the list.

# %%
lst=["ab","cde","erty","sultan","ineuron"]

# %%
def check_length(your_list):
    l=[]
    for item in range(0,len(your_list)):
        l.append(len(your_list[item]))
    print(l)

# %%
length_of_list(lst)
# Out:
# [2, 3, 4, 6, 7]

# %%
# 2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if
# it is a vowel, False otherwise.

# %%
def check_vowel(string):
    if string in ["a","e","i","o","u"]:
        return True
    else:
        return False

# %%
check_vowel("aaa")
# Out:
# False
